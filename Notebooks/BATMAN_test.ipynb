# %%
# %matplotlib notebook
import batman
import numpy as np
import matplotlib.pyplot as plt

# %%
params = batman.TransitParams()
params.t0 = 0. #Transit time of inferior conjunction
params.per = 1. #Orbital period in days
params.rp = 0.1 #planet radius as a fraction of star radius
params.a = 15. #semi-major axis as a fraction of star radius
params.inc = 87. #orbital inclination (degrees)
params.ecc =0. #eccentricity
params.w = 90. #longitude of periastron (deg)
params.u = [0.1, 0.3] #limb darkening coefficients
params.limb_dark = 'quadratic' #limb darkening model

# %%
t = np.linspace(-0.2,0.2, 1000)

# %%
m = batman.TransitModel(params, t) #initialises model
flux = m.light_curve(params) #calculates light curve

# %%
plt.figure(num=1, figsize=[9.8,4.2])
plt.plot(t,flux)
plt.xlabel('Time from central transit (days)')
plt.ylabel('Relative flux')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="980">

# %%
#WASP-18b system parameters from Shporer et.al.
params.per = 0.9414526
params.rp = 0.09716
params.a = 3.562
params.ecc = 0.0091
params.inc = 84.88
params.w = 269
params.u = [0.2192, 0.3127]

# %%
t = np.linspace(-0.2, 0.2, 1000)
m = batman.TransitModel(params, t)
flux = m.light_curve(params)

# %%
plt.figure(num=2, figsize=[9.8,4.2])
plt.plot(t,flux)
plt.xlabel('Time from central transit (days)')
plt.ylabel('relative flux')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="980">
